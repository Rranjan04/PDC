# %% [markdown]
# # Modules Used:
# ### 1) time module :
#     for timing the runtime
#
#
# ### 2) PIL module:
#     for image processing
#
#
# ### 3) concurrent.futures module:
#     for asynchronously executing callables
#
#
# ### 4) numpy, pandas and matplotlib :
#     for visualization and analysis

# %% [markdown]
# # Set of Images and required modules for Image Processing

# %%
import time
from PIL import Image, ImageFilter
import concurrent.futures

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)

# %% [markdown]
# # Gaussian Blur

# %%
#SERIAL
import time
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.GaussianBlur(15))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed
# photo-1550439062-609e1531270e.jpg was processed
# photo-1493976040374-85c8e12f0c0e.jpg was processed
# photo-1504198453319-5ce911bafcde.jpg was processed
# photo-1507143550189-fed454f93097.jpg was processed
# photo-1513938709626-033611b8cc03.jpg was processed
# photo-1516117172878-fd2c41f4a759.jpg was processed
# photo-1516972810927-80185027ca84.jpg was processed
# photo-1522364723953-452d3431c267.jpg was processed
# photo-1524429656589-6633a470097c.jpg was processed
# photo-1530122037265-a5f1f91d3b99.jpg was processed
# photo-1530224264768-7ff8c1789d79.jpg was processed
# photo-1532009324734-20a7a5813719.jpg was processed
# photo-1541698444083-023c97d3f4b6.jpg was processed
# photo-1564135624576-c5c88640f235.jpg was processed
# Process Finished in 16.079917555001884 secs.

# %%
#PARELLAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.GaussianBlur(15))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian,img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# Process Finished in 10.789342525000393 secs.

# %% [markdown]
# # Box Blur

# %%
# SERIAL
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.BoxBlur(4))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 22.811034599999402 secs.

# %%
# PARELLAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.BoxBlur(4))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian,img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# Process Finished in 7.066145807999419 secs.

# %% [markdown]
# # Unsharp Mask

# %%
# SERIAL 
import time
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.UnsharpMask(2,150,3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 18.588272449000215 secs.

# %%
# PARELLAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.UnsharpMask(2,150,3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian,img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# Process Finished in 9.538991143999738 secs.

# %% [markdown]
# # Rank Filter

# %%
# SERIAL
import time
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.RankFilter(3, 8))  # max filter
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 68.79649729800076 secs.

# %%
# Parellal
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.RankFilter(3,8))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian,img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...photo-1550439062-609e1531270e.jpg was processed ...
#
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 21.63507284699881 secs.

# %% [markdown]
# # Max Filter

# %%
#SERIAL 
import time
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.MaxFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 63.46483548699689 secs.

# %%
# PARELLAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.MaxFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian, img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 20.791486457001156 secs.

# %% [markdown]
# # Median Filter

# %%
#SERIAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.MedianFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
    
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 81.48070640199876 secs.

# %%
# Parellal
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.MedianFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian,img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 25.08273483999801 secs.

# %% [markdown]
# # Min Filter

# %%
# SERIAL
import time
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.MinFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 66.45868491100191 secs.

# %%
# PARELLAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.MinFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian, img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 22.055500345999462 secs.

# %% [markdown]
# # Mode Filter

# %%
#SERIAL
import time
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)
for img_name in img_names:
    img = Image.open(img_name)
    img = img.filter(ImageFilter.ModeFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# Process Finished in 212.0494746229997 secs.

# %%
# PARELLAL
import time
import concurrent.futures
from PIL import Image, ImageFilter

t1 = time.perf_counter()
img_names = ['photo-1549692520-acc6669e2f0c.jpg',
             'photo-1550439062-609e1531270e.jpg',
             'photo-1493976040374-85c8e12f0c0e.jpg',
             'photo-1504198453319-5ce911bafcde.jpg',
             'photo-1507143550189-fed454f93097.jpg',
             'photo-1513938709626-033611b8cc03.jpg',
             'photo-1516117172878-fd2c41f4a759.jpg',
             'photo-1516972810927-80185027ca84.jpg',
             'photo-1522364723953-452d3431c267.jpg',
             'photo-1524429656589-6633a470097c.jpg',
             'photo-1530122037265-a5f1f91d3b99.jpg',
             'photo-1530224264768-7ff8c1789d79.jpg',
             'photo-1532009324734-20a7a5813719.jpg',
             'photo-1541698444083-023c97d3f4b6.jpg',
             'photo-1564135624576-c5c88640f235.jpg'
             ]
size = (1200, 1200)


def img_proc_gaussian(img_name):
    img = Image.open(img_name)
    img = img.filter(ImageFilter.ModeFilter(3))
    img.thumbnail(size)
    # img.save(f'new_images/{img_name}')
    print(f'{img_name} was processed ...')


with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(img_proc_gaussian, img_names)
t2 = time.perf_counter()
print(f'Process Finished in {t2 - t1} secs.')
# Out:
# photo-1516117172878-fd2c41f4a759.jpg was processed ...
# photo-1507143550189-fed454f93097.jpg was processed ...
# photo-1516972810927-80185027ca84.jpg was processed ...
# photo-1549692520-acc6669e2f0c.jpg was processed ...
# photo-1550439062-609e1531270e.jpg was processed ...
# photo-1513938709626-033611b8cc03.jpg was processed ...
# photo-1522364723953-452d3431c267.jpg was processed ...
# photo-1524429656589-6633a470097c.jpg was processed ...
# photo-1504198453319-5ce911bafcde.jpg was processed ...
# photo-1530122037265-a5f1f91d3b99.jpg was processed ...
# photo-1493976040374-85c8e12f0c0e.jpg was processed ...
# photo-1530224264768-7ff8c1789d79.jpg was processed ...
# photo-1532009324734-20a7a5813719.jpg was processed ...
# photo-1564135624576-c5c88640f235.jpg was processed ...
# photo-1541698444083-023c97d3f4b6.jpg was processed ...
# Process Finished in 62.72706505599854 secs.

# %% [markdown]
# # ANALYSIS AND VISUALIZATION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_excel("./Exec_Time.xlsx")
df['Speed_up'] = df['Serial_Time']/df['Parellal_Time']

# %%
df
# Out:
#    Sr.no         Filter  Serial_Time  Parellal_Time  Speed_up
# 0      0  Gaussian Blur    14.619095       4.730727  3.090243
# 1      1       Box Blur    12.920546       2.769959  4.664526
# 2      2   Unsharp Mask    17.454224       5.581040  3.127414
# 3      3    Rank Filter    65.979769      22.178657  2.974922
# 4      4     Max Filter    70.209665      23.731326  2.958523
# 5      5  Median Filter    74.945704      21.488905  3.487646
# 6      6     Min Filter    66.655078      22.120736  3.013240
# 7      7    Mode Filter   197.864574      59.599289  3.319915

# %%
fig, ax = plt.subplots(figsize=(15, 6))
pname = df['Filter'].values
x = np.arange(len(pname))
w = 0.4
plt.grid(True)
plt.bar(x-w,df['Serial_Time'].values, width=w, label="Serial Execution Time",alpha = 0.5)
plt.bar(x,df['Parellal_Time'].values, width=w, label="Parellal Execution Time",alpha = 0.5)

plt.xticks(x,pname)
plt.xticks
plt.ylim([0,200])
plt.tight_layout()
plt.xlabel('Filter')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 6))
pname = df['Filter'].values
x = np.arange(len(pname))
w = 0.4
plt.grid(True)
plt.plot(x,df['Speed_up'].values,lw=4,label = "Speed Up",marker = 'o',markersize = 9,linestyle = 'dashed',markerfacecolor = 'red')
plt.xticks(x,pname)
plt.xticks
plt.ylim([0,7])
plt.tight_layout()
plt.xlabel('Filter')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5,)
plt.show()

# %% [markdown]
# # INFERENCE
#
# From the outputs above , it can be seen that the parellalisation of Image Processing transformations have reduced the transformation time immensly . Besides an average speedup of around 3.1 has been acheived.
